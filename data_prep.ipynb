# %%
import os
import pandas as pd
import numpy as np
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
data_fn = '211205wave2e.csv'

df = pd.read_csv(data_fn)

# Data Prep
all_cols = df.columns
all_cols

df
# Out:
#       W2_Age_year  W2_Gender  W2_Relationship  W2_Keyworker  \
# 0              35          2                2             0
# 1              34          2                3             0
# 2              31          1                1             1
# 3              40          2                1             0
# 4              50          1                3             0
# 5              43          1                3             0
# 6              74          2                6             0
# 7              67          2                6             0
# 8              46          1                1             1
# 9              45          2                3             0
# 10             41          2               11             0
# 11             69          1                4             0
# 12             72          1                1             0
# 13             79          1                1             0
# 14             58          1                1             0
# ...

# %%
# # Data Prep
# all_cols = df.columns
# cat_cols = ['gender', 'orientation', 'rel_status', 'children', 'religion']
# cont_cols = list(set(all_cols) - set(cat_cols))

# df[cat_cols] = df[cat_cols].astype('category')

# new_cols = []
# for col in cat_cols:
#     new_col = col+'_coded'
#     new_cols.append(new_col)
#     df[new_col] = df[col].cat.codes
    
# analysis_cols = cont_cols + new_cols
# df_A = df[analysis_cols]

# %%
# impute = 1


# if impute == 1:
#     cols = df_A.columns
#     imp = IterativeImputer(max_iter=100, random_state=0, estimator=None)
#     imp.fit(df_A)
#     IterativeImputer(random_state=0)
#     df_A = pd.DataFrame(data=imp.transform(df_A), columns=cols)

# df_A.to_csv('coded_data.csv', index=False)
